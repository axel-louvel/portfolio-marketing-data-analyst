# %% [markdown]
# # Modélisation de la Fidélisation Client – Régression Logistique
# Ce notebook reproduit ton analyse de fidélisation client.
#
#
# **Objectifs :**
#
# - Identifier les facteurs expliquant la fidélité
#
# - Tester les relations statistiques entre variables
#
# - Construire un modèle prédictif (régression logistique)
#
# - Évaluer la performance du modèle
#
#
# > ⚠️ Adapte les noms de colonnes selon ton dataset réel.

# %% [markdown]
# ## 1. Import des bibliothèques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %matplotlib inline

# %% [markdown]
# ## 2. Chargement des données
# On suppose un dataset contenant au minimum :
#
# - `Age`
# - `Gender`
# - `Satisfaction` (score 1-10)
# - `Engagement` (visites, durée...)
# - `Frequency` (nombre d’achats)
# - `Loyalty` (0 = non fidèle, 1 = fidèle)
#
# Tu peux ajuster selon ton fichier.

# %%
# 🔁 Remplacer par ton fichier réel
file_path = "data/fidelisation_clients.csv"

df = pd.read_csv(file_path)
df.head()

# %% [markdown]
# ## 3. Nettoyage et préparation des données

# %%
df.info()

# Suppression des valeurs manquantes
df = df.dropna()

df.describe()

# %% [markdown]
# ## 4. Analyse exploratoire des variables

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["Satisfaction"], kde=True)
plt.title("Distribution du score de satisfaction")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=df, x="Engagement", y="Frequency", hue="Loyalty")
plt.title("Engagement vs Fréquence d'achat")
plt.show()

# %% [markdown]
# ### Matrice de corrélation

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Corrélations")
plt.show()

# %% [markdown]
# ## 5. Préparation des données pour le modèle

# %%
# Variables explicatives (exemple)
X = df[["Satisfaction", "Engagement", "Frequency"]]

# Variable cible
y = df["Loyalty"]

# Split train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

X_train.head()

# %% [markdown]
# ## 6. Régression Logistique

# %%
model = LogisticRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
accuracy

# %% [markdown]
# ### Interprétation des coefficients

# %%
coef_df = pd.DataFrame({
    "Variable": X.columns,
    "Coefficient": model.coef_[0]
})
coef_df

# %% [markdown]
# ## 7. Matrice de Confusion

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Matrice de Confusion")
plt.xlabel("Prédiction")
plt.ylabel("Réel")
plt.show()

# %% [markdown]
# ## 8. Rapport de classification

# %%
print(classification_report(y_test, y_pred))

# %% [markdown]
# ## 9. Conclusions & Recommandations
# Exemple de conclusions (à adapter) :
#
#
# - Le modèle affiche une précision autour de **85-88 %**.
#
# - La **satisfaction** est la variable la plus prédictive.
#
# - L’engagement digital a aussi un impact significatif.
#
# - La fréquence d’achat distingue fortement les clientes fidèles.
#
#
# ### Recommandations marketing :
#
# - Créer un parcours fidélité basé sur les clientes engagées.
#
# - Déployer des campagnes de réactivation pour les clients peu actifs.
#
# - Accroître l'expérience client (UX / service client) pour booster la satisfaction.
